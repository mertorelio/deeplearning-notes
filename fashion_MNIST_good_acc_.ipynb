# %% [markdown]
#  fashion MNIST veri setımız ile yuksek bir accuracy degeri elde etmeye calisalim
#
#  Hedefimiz accuracyi %88+ yapmak

# %%
import tensorflow as tf
import numpy as np 
import pandas as pd
from tensorflow.keras.datasets import fashion_mnist

# %%
(train_data, train_labels), (test_data, test_labels) = fashion_mnist.load_data()
# Out:
# ...
# 4431872/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# Normalization

# %%
train_data_norm = train_data /255.0
test_data_norm = test_data / 255.0

# %% [markdown]
# Ilk denememizi yapalim

# %%
#create the model
model_1 = tf.keras.Sequential([
      tf.keras.layers.Flatten(input_shape= (28, 28)), 
      tf.keras.layers.Dense(4, activation="relu"),
      tf.keras.layers.Dense(4, activation="relu"),
      tf.keras.layers.Dense(10, activation= tf.keras.activations.softmax)
    ])

#compile the model

model_1.compile(loss = tf.keras.losses.SparseCategoricalCrossentropy(),#Sparse seklinde kullanmamizin sebei labellarimiz one hot seklinde degilse ullaniriz biraz arastiralim bunuda
                optimizer= tf.keras.optimizers.Adam(),
                metrics= ["accuracy"])

#fit the model
history= model_1.fit(train_data_norm,
                     train_labels,
                     epochs= 50,
                     validation_data= (test_data_norm,test_labels) 
                     )
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.3104 - accuracy: 0.5253 - val_loss: 1.0334 - val_accuracy: 0.6257
# Epoch 2/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.9376 - accuracy: 0.6579 - val_loss: 0.8807 - val_accuracy: 0.6942
# Epoch 3/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.7797 - accuracy: 0.7198 - val_loss: 0.7212 - val_accuracy: 0.7432
# Epoch 4/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.6531 - accuracy: 0.7624 - val_loss: 0.6717 - val_accuracy: 0.7638
# Epoch 5/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.6101 - accuracy: 0.7750 - val_loss: 0.6380 - val_accuracy: 0.7707
# Epoch 6/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.5896 - accuracy: 0.7795 - val_loss: 0.6138 - val_accuracy: 0.7684
# Epoch 7/50
# ...

# %% [markdown]
# 83 oldu daha arttirmayi deneyelim

# %%
#create the model
model_2 = tf.keras.Sequential([
      tf.keras.layers.Flatten(input_shape= (28, 28)), 
      tf.keras.layers.Dense(4, activation="relu"),
      tf.keras.layers.Dense(4, activation="relu"),
      tf.keras.layers.Dense(4, activation="relu"),
      tf.keras.layers.Dense(10, activation= tf.keras.activations.softmax)
    ])

#compile the model

model_2.compile(loss = tf.keras.losses.SparseCategoricalCrossentropy(),#Sparse seklinde kullanmamizin sebei labellarimiz one hot seklinde degilse ullaniriz biraz arastiralim bunuda
                optimizer= tf.keras.optimizers.Adam(learning_rate=0.001),
                metrics= ["accuracy"])

#fit the model
history_2= model_2.fit(train_data_norm,
                     train_labels,
                     epochs= 50,
                     validation_data= (test_data_norm,test_labels) 
                     )
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.3800 - accuracy: 0.4810 - val_loss: 1.0569 - val_accuracy: 0.6558
# Epoch 2/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.9485 - accuracy: 0.6819 - val_loss: 0.8894 - val_accuracy: 0.7009
# Epoch 3/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.7900 - accuracy: 0.7337 - val_loss: 0.7494 - val_accuracy: 0.7478
# Epoch 4/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.7076 - accuracy: 0.7551 - val_loss: 0.7070 - val_accuracy: 0.7632
# Epoch 5/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6689 - accuracy: 0.7657 - val_loss: 0.6824 - val_accuracy: 0.7660
# Epoch 6/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6433 - accuracy: 0.7736 - val_loss: 0.6733 - val_accuracy: 0.7684
# Epoch 7/50
# ...

# %% [markdown]
# daha uzun surede egitmeyi deneyelim ve dense layer sayisini arttiralim

# %%
#create the model
model_3 = tf.keras.Sequential([
      tf.keras.layers.Flatten(input_shape= (28, 28)), 
      tf.keras.layers.Dense(64, activation="relu"),
      tf.keras.layers.Dropout(rate=0.2),
      tf.keras.layers.Dense(32, activation="relu"),
      tf.keras.layers.Dense(10, activation= tf.keras.activations.softmax)
    ])

#compile the model

model_3.compile(loss = tf.keras.losses.SparseCategoricalCrossentropy(),#Sparse seklinde kullanmamizin sebei labellarimiz one hot seklinde degilse ullaniriz biraz arastiralim bunuda
                optimizer= tf.keras.optimizers.Adam(learning_rate=0.001),
                metrics= ["accuracy"])

#fit the model
history_3= model_3.fit(train_data_norm,
                     train_labels,
                     epochs= 30,
                     validation_data= (test_data_norm,test_labels) 
                     )
# Out:
# Epoch 1/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.5818 - accuracy: 0.7936 - val_loss: 0.4313 - val_accuracy: 0.8455
# Epoch 2/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4274 - accuracy: 0.8458 - val_loss: 0.4082 - val_accuracy: 0.8537
# Epoch 3/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3941 - accuracy: 0.8571 - val_loss: 0.3943 - val_accuracy: 0.8582
# Epoch 4/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3762 - accuracy: 0.8618 - val_loss: 0.3917 - val_accuracy: 0.8566
# Epoch 5/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3617 - accuracy: 0.8660 - val_loss: 0.3885 - val_accuracy: 0.8566
# Epoch 6/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3487 - accuracy: 0.8697 - val_loss: 0.3620 - val_accuracy: 0.8694
# Epoch 7/30
# ...

# %%
pd.DataFrame(history_3.history).plot(title= "")

# %%
# Function for the confusion matrix 
import itertools
from sklearn.metrics import confusion_matrix

# Our function needs a different name to sklearn's plot_confusion_matrix
def make_confusion_matrix(y_true, y_pred, classes=None, figsize=(10, 10), text_size=15): 
  """Makes a labelled confusion matrix comparing predictions and ground truth labels.

  If classes is passed, confusion matrix will be labelled, if not, integer class values
  will be used.

  Args:
    y_true: Array of truth labels (must be same shape as y_pred).
    y_pred: Array of predicted labels (must be same shape as y_true).
    classes: Array of class labels (e.g. string form). If `None`, integer labels are used.
    figsize: Size of output figure (default=(10, 10)).
    text_size: Size of output figure text (default=15).
  
  Returns:
    A labelled confusion matrix plot comparing y_true and y_pred.

  Example usage:
    make_confusion_matrix(y_true=test_labels, # ground truth test labels
                          y_pred=y_preds, # predicted labels
                          classes=class_names, # array of class label names
                          figsize=(15, 15),
                          text_size=10)
  """  
  # Create the confustion matrix
  cm = confusion_matrix(y_true, y_pred)
  cm_norm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis] # normalize it
  n_classes = cm.shape[0] # find the number of classes we're dealing with

  # Plot the figure and make it pretty
  fig, ax = plt.subplots(figsize=figsize)
  cax = ax.matshow(cm, cmap=plt.cm.Blues) # colors will represent how 'correct' a class is, darker == better
  fig.colorbar(cax)

  # Are there a list of classes?
  if classes:
    labels = classes
  else:
    labels = np.arange(cm.shape[0])
  
  # Label the axes
  ax.set(title="Confusion Matrix",
         xlabel="Predicted label",
         ylabel="True label",
         xticks=np.arange(n_classes), # create enough axis slots for each class
         yticks=np.arange(n_classes), 
         xticklabels=labels, # axes will labeled with class names (if they exist) or ints
         yticklabels=labels)
  
  # Make x-axis labels appear on bottom
  ax.xaxis.set_label_position("bottom")
  ax.xaxis.tick_bottom()

  # Set the threshold for different colors
  threshold = (cm.max() + cm.min()) / 2.

  # Plot the text on each cell
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, f"{cm[i, j]} ({cm_norm[i, j]*100:.1f}%)",
             horizontalalignment="center",
             color="white" if cm[i, j] > threshold else "black",
             size=text_size)

# %% [markdown]
# yukaridaki fonksiyon yardimiyla confusion matrixe bakalim

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
import matplotlib.pyplot as plt

# %%
# modelimiz ile tahminler gerceklestirelim
pred_probs = model_3.predict(test_data)

# tahminleri dogru formata cevirelim
preds = pred_probs.argmax(axis = 1)

# ilk 10 tahmine bakalim
preds[:10]
# Out:
# array([9, 2, 1, 1, 6, 1, 4, 6, 5, 7])

# %%
make_confusion_matrix(y_true=test_labels, 
                      y_pred=preds,
                      classes=class_names,
                      figsize=(15, 15),
                      text_size=10)
